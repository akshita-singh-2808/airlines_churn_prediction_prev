# %% [markdown]
# <a href="https://colab.research.google.com/github/akshita-singh-2808/airlines_churn_prediction/blob/main/02_Model_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/airlines_churn_prediction/outputs/Modeling_Dataset.csv')

# %%
df
# Out:
#        Loyalty Number  Male_Enc  Education_Enc  Marital_Enc  Card_Enc  \
# 0              480934         0              2            1         0
# 1              549612         1              1            2         0
# 2              429460         1              1            0         0
# 3              608370         1              1            0         0
# 4              530508         1              2            1         0
# ...               ...       ...            ...          ...       ...
# 14238          302460         0              2            1         0
# 14239          900501         1              1            0         0
# 14240          823768         0              1            1         0
# 14241          680886         0              2            1         0
# 14242          776187         1              1            0         0
#
#        Salary_Imputed  Salary_Was_Imputed       CLV  Tenure  Promo_Enroll  \
# ...
